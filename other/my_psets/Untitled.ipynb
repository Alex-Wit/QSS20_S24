# %%
## helpful packages
import pandas as pd
import numpy as np
import random
import re
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"


# Now we work on loading and inspecting the data sets

# %%
import pickle
import pandas as pd

# File path
file_path = '/Users/alexwitheiler/Downloads/covid_sample-0.001.pkl'

data = pd.read_pickle(file_path)

# Now we can work with 'data' DataFrame
data.head
# Out:
# <bound method NDFrame.head of                     tweetid               userid    screen_name  \
# 15605   1220641644367765504   747463650881970176   gareth_grier
# 16910   1220640235358281729   937270922234363905      Rose_ifnt
# 8796    1220632931489574913           3869545214     SinoVoices
# 14795   1220642433127436288           1053953342  _KhairiHassan
# 4225    1220640550178762753  1104714610421190656    Gaz60656269
# ...                     ...                  ...            ...
# 90900   1482664673854038016            508859323      laudemare
# 22201   1482656524245909507  1390529577760530433     Justbob111
# 81791   1482663571716775936  1464936163123281923     falcon2800
# 88826   1482664418727145473            798161712    KevinSalvat
# 102639  1482666092438953995  1327585064541106177   claveledith1
#
#                                   date lang       location place_id place_url  \
# 15605   Fri Jan 24 09:37:01 +0000 2020   en            NaN      NaN       NaN
# ...

# %%
import pandas as pd

# Path to the file
file_path = '/Users/amanda/Downloads/tweets_list.pkl'

# Load the data from the pickle file
data = pd.read_pickle(file_path)

# Display the first few rows of the dataframe
data

columns = ['username', 'location', 'description', 'followers', 'verified', 'tweet', 'datetime', 'extra_column']
df = pd.DataFrame(data, columns=columns)

# Handle missing values or extra columns
df.drop(columns=['extra_column'], inplace=True)  # Remove if not needed
df.fillna('Missing')  # Fill missing data
